# %% [markdown]
# # 1. Installing Python packages

# %%
# !pip install tensorflow==2.12.0 tensorflowjs==2.0.0 opencv-python mediapipe scikit-learn
# Out:
# Requirement already satisfied: tensorflow==2.12.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (2.12.0)
# Requirement already satisfied: tensorflowjs==2.0.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (2.0.0)
# Requirement already satisfied: opencv-python in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (4.9.0.80)
# Requirement already satisfied: mediapipe in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (0.10.11)
# Requirement already satisfied: scikit-learn in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (1.4.2)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: h5py>=2.8.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflowjs==2.0.0) (3.11.0)
# Requirement already satisfied: numpy>=1.16.4 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflowjs==2.0.0) (1.23.5)
# Requirement already satisfied: six>=1.12.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflowjs==2.0.0) (1.16.0)
# Requirement already satisfied: tensorflow-cpu>=2.1.0<3 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflowjs==2.0.0) (2.12.0)
# Requirement already satisfied: tensorflow-hub==0.7.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflowjs==2.0.0) (0.7.0)
# Requirement already satisfied: PyInquirer==1.0.3 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflowjs==2.0.0) (1.0.3)
# Collecting prompt-toolkit==1.0.14 (from PyInquirer==1.0.3->tensorflowjs==2.0.0)
#   Using cached prompt_toolkit-1.0.14-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: Pygments>=2.2.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from PyInquirer==1.0.3->tensorflowjs==2.0.0) (2.17.2)
# Requirement already satisfied: regex>=2016.11.21 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from PyInquirer==1.0.3->tensorflowjs==2.0.0) (2024.4.28)
# Requirement already satisfied: protobuf>=3.4.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-hub==0.7.0->tensorflowjs==2.0.0) (3.20.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (24.3.25)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.2.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.4.26)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.3.0)
# Requirement already satisfied: packaging in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (24.0)
# Requirement already satisfied: setuptools in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (65.5.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (4.11.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.63.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.31.0)
# Requirement already satisfied: wcwidth in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from prompt-toolkit==1.0.14->PyInquirer==1.0.3->tensorflowjs==2.0.0) (0.2.13)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (23.2.0)
# Requirement already satisfied: matplotlib in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (3.8.4)
# Requirement already satisfied: opencv-contrib-python in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (4.9.0.80)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.4.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.43.0)
# Requirement already satisfied: pycparser in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.29.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.0.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\radu.suciu\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.2.2)
# Using cached prompt_toolkit-1.0.14-py3-none-any.whl (248 kB)
# Installing collected packages: prompt-toolkit
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.43
#     Uninstalling prompt-toolkit-3.0.43:
#       Successfully uninstalled prompt-toolkit-3.0.43
# Successfully installed prompt-toolkit-1.0.14
# DEPRECATION: tensorflowjs 2.0.0 has a non-standard dependency specifier tensorflow-cpu>=2.1.0<3. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of tensorflowjs or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 8.24.0 requires prompt-toolkit<3.1.0,>=3.0.41, but you have prompt-toolkit 1.0.14 which is incompatible.
# jupyter-console 6.6.3 requires prompt-toolkit>=3.0.30, but you have prompt-toolkit 1.0.14 which is incompatible.

# %% [markdown]
# # 2. Importing libraries

# %%
import cv2
import numpy as np
import os
import time
import mediapipe as mp
import tensorflowjs as tfjs
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import TensorBoard
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D,Flatten, LSTM, Dense, Dropout, Input
from keras.optimizers import Adam
from keras.regularizers import l2

# %% [markdown]
# # 3. Creating variables

# %%
DATA_PATH = os.path.join('MP_Data')
signs = np.array([chr(i) for i in range(ord('A'), ord('Z')+1)] + ['next', 'space', 'backspace'])
mp_hands = mp.solutions.hands
modelH = mp_hands.Hands(static_image_mode=True, min_detection_confidence=0.4)
drawing_utils = mp.solutions.drawing_utils
drawing_styles = mp.solutions.drawing_styles
data_for_each_sign = 100
data_length = 45
sign_map = {sign: index for index, sign in enumerate(signs)}
labels_array = np.zeros((29*100, 29), dtype=int)
for i in range(29):
    labels_array[i*100:(i+1)*100, i] = 1

# %% [markdown]
# # 4. Defining usefull functions

# %%
def get_data(results):
    if results.multi_hand_landmarks:
        landmarks = results.multi_hand_landmarks[0].landmark
        arr = np.array([[landmark.x, landmark.y, landmark.z] for landmark in landmarks]).flatten()
    else:
        arr = np.zeros(63)
    return arr

# %%
def draw_landmarks(results, frame):
    if results.multi_hand_landmarks:
        for landmark in results.multi_hand_landmarks:
            drawing_utils.draw_landmarks(
                frame,  
                landmark,
                mp_hands.HAND_CONNECTIONS, 
                drawing_styles.get_default_hand_landmarks_style(),
                drawing_styles.get_default_hand_connections_style())
    return frame

# %% [markdown]
# # 5. Collecting data for training

# %%
for sign in signs: 
    for index in range(data_for_each_sign):
        try: 
            os.makedirs(os.path.join(DATA_PATH, sign, str(index)))
        except:
            pass

# %%
cap = cv2.VideoCapture(0)
for sign in signs:
    for index in range(data_for_each_sign):
        for data_index in range(data_length):
            ret, frame = cap.read()
            frame_flipped = cv2.flip(frame, 1)
            image = cv2.cvtColor(frame_flipped, cv2.COLOR_BGR2RGB)
            results = modelH.process(image) 

            drawn_frame = draw_landmarks(results, frame_flipped)
           
            if data_index != 0: 
                cv2.imshow('Frame', drawn_frame)
            else:
                cv2.rectangle(drawn_frame, (50,50), (150,150), (0, 0, 255), -1)
                cv2.putText(drawn_frame, sign, (75, 125), cv2.FONT_HERSHEY_SIMPLEX, 3, (0, 0, 0), 5)
                cv2.imshow('Frame', drawn_frame)
                cv2.waitKey(1000)
                
            np.save(os.path.join(DATA_PATH, sign, str(index), str(data_index)), get_data(results))
            
            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
                    
cap.release()
cv2.destroyAllWindows()

# %%
all_data = []
for sign in signs:
    for index in range(data_for_each_sign):
        video = []
        for data_index in range(data_length):
            loaded_data = np.load(os.path.join(DATA_PATH, sign, str(index), "{}.npy".format(data_index)))
            video.append(loaded_data)
        all_data.append(video)

# %%
X = np.array(all_data)
Y = labels_array
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y)

# %% [markdown]
# # 6. Creating and Training Model

# %%
model = Sequential()

# Input layer
input_layer = Input(shape=(45, 63), name='input_layer')
model.add(input_layer)

# Convolutional layers
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))

# LSTM layers
model.add(LSTM(64, return_sequences=True))
model.add(Dropout(0.5))

model.add(LSTM(64))
model.add(Dropout(0.5))

# Dense layers
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(29, activation='softmax')) # Assuming 29 classes

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, Y_train, epochs=200)
# Out:
# Epoch 1/200
# 73/73 [==============================] - 3s 11ms/step - loss: 3.3622 - accuracy: 0.0392
# Epoch 2/200
# 73/73 [==============================] - 1s 11ms/step - loss: 2.9098 - accuracy: 0.1259
# Epoch 3/200
# 73/73 [==============================] - 1s 11ms/step - loss: 2.3888 - accuracy: 0.2026
# Epoch 4/200
# 73/73 [==============================] - 1s 11ms/step - loss: 2.0021 - accuracy: 0.3034
# Epoch 5/200
# 73/73 [==============================] - 1s 11ms/step - loss: 1.6302 - accuracy: 0.3728
# Epoch 6/200
# 73/73 [==============================] - 1s 11ms/step - loss: 1.6066 - accuracy: 0.3961
# Epoch 7/200
# 73/73 [==============================] - 1s 11ms/step - loss: 1.3615 - accuracy: 0.4703
# Epoch 8/200
# 73/73 [==============================] - 1s 12ms/step - loss: 1.2725 - accuracy: 0.5224
# Epoch 9/200
# 73/73 [==============================] - 1s 12ms/step - loss: 1.0311 - accuracy: 0.5953
# Epoch 10/200
# 73/73 [==============================] - 1s 11ms/step - loss: 1.0490 - accuracy: 0.5845
# Epoch 11/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.9142 - accuracy: 0.6414
# Epoch 12/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.8884 - accuracy: 0.6591
# Epoch 13/200
# 73/73 [==============================] - 1s 13ms/step - loss: 1.0229 - accuracy: 0.6297
# Epoch 14/200
# 73/73 [==============================] - 1s 13ms/step - loss: 0.6997 - accuracy: 0.7272
# Epoch 15/200
# 73/73 [==============================] - 1s 13ms/step - loss: 0.6427 - accuracy: 0.7491
# Epoch 16/200
# 73/73 [==============================] - 1s 13ms/step - loss: 0.6235 - accuracy: 0.7565
# Epoch 17/200
# 73/73 [==============================] - 1s 13ms/step - loss: 0.4632 - accuracy: 0.8172
# Epoch 18/200
# 73/73 [==============================] - 1s 13ms/step - loss: 0.5590 - accuracy: 0.8022
# Epoch 19/200
# 73/73 [==============================] - 1s 13ms/step - loss: 0.6453 - accuracy: 0.7728
# Epoch 20/200
# 73/73 [==============================] - 1s 13ms/step - loss: 0.4698 - accuracy: 0.8172
# Epoch 21/200
# 73/73 [==============================] - 1s 12ms/step - loss: 0.8522 - accuracy: 0.7168
# Epoch 22/200
# 73/73 [==============================] - 1s 13ms/step - loss: 0.7492 - accuracy: 0.7302
# Epoch 23/200
# 73/73 [==============================] - 1s 12ms/step - loss: 0.3937 - accuracy: 0.8595
# Epoch 24/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3685 - accuracy: 0.8616
# Epoch 25/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3848 - accuracy: 0.8552
# Epoch 26/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.3740 - accuracy: 0.8703
# Epoch 27/200
# 73/73 [==============================] - 1s 11ms/step - loss: 0.5810 - accuracy: 0.8091
# Epoch 28/200
# 73/73 [==============================] - 1s 12ms/step - loss: 0.3749 - accuracy: 0.8625
# Epoch 29/200
# 73/73 [==============================] - 1s 12ms/step - loss: 0.3148 - accuracy: 0.8845
# Epoch 30/200
# 73/73 [==============================] - 1s 12ms/step - loss: 0.3034 - accuracy: 0.9000
# Epoch 31/200
# 73/73 [==============================] - 1s 12ms/step - loss: 0.3772 - accuracy: 0.8659
# Epoch 32/200
# 73/73 [==============================] - 1s 12ms/step - loss: 0.8348 - accuracy: 0.7496
# Epoch 33/200
# 73/73 [==============================] - 1s 13ms/step - loss: 0.2776 - accuracy: 0.9047
# Epoch 34/200
# 73/73 [==============================] - 1s 12ms/step - loss: 0.2024 - accuracy: 0.9362
# Epoch 35/200
# 73/73 [==============================] - 1s 12ms/step - loss: 0.2319 - accuracy: 0.9190
# Epoch 36/200
# 73/73 [==============================] - 1s 12ms/step - loss: 0.5004 - accuracy: 0.8534
# Epoch 37/200
# 73/73 [==============================] - 1s 14ms/step - loss: 0.4139 - accuracy: 0.8616
# Epoch 38/200
# 73/73 [==============================] - 1s 14ms/step - loss: 0.2470 - accuracy: 0.9185
# Epoch 39/200
# 73/73 [==============================] - 1s 16ms/step - loss: 0.2000 - accuracy: 0.9293
# Epoch 40/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.2531 - accuracy: 0.9172
# Epoch 41/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.8895 - accuracy: 0.7707
# Epoch 42/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.4904 - accuracy: 0.8427
# Epoch 43/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.2090 - accuracy: 0.9414
# Epoch 44/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.2242 - accuracy: 0.9319
# Epoch 45/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.3089 - accuracy: 0.8991
# Epoch 46/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.2220 - accuracy: 0.9323
# Epoch 47/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.2613 - accuracy: 0.9151
# Epoch 48/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1667 - accuracy: 0.9466
# Epoch 49/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1556 - accuracy: 0.9474
# Epoch 50/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.4564 - accuracy: 0.8767
# Epoch 51/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.3076 - accuracy: 0.9082
# Epoch 52/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.7755 - accuracy: 0.7953
# Epoch 53/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.2639 - accuracy: 0.9159
# Epoch 54/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.1344 - accuracy: 0.9703
# Epoch 55/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.2138 - accuracy: 0.9358
# Epoch 56/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1766 - accuracy: 0.9444
# Epoch 57/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1289 - accuracy: 0.9616
# Epoch 58/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.8136 - accuracy: 0.7996
# Epoch 59/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.2094 - accuracy: 0.9392
# Epoch 60/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1503 - accuracy: 0.9634
# Epoch 61/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.2211 - accuracy: 0.9358
# Epoch 62/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.2066 - accuracy: 0.9375
# Epoch 63/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1651 - accuracy: 0.9513
# Epoch 64/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1106 - accuracy: 0.9728
# Epoch 65/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.4978 - accuracy: 0.8849
# Epoch 66/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.1732 - accuracy: 0.9487
# Epoch 67/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1125 - accuracy: 0.9716
# Epoch 68/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0907 - accuracy: 0.9789
# Epoch 69/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1772 - accuracy: 0.9517
# Epoch 70/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.2219 - accuracy: 0.9353
# Epoch 71/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0976 - accuracy: 0.9724
# Epoch 72/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.2004 - accuracy: 0.9461
# Epoch 73/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.2483 - accuracy: 0.9345
# Epoch 74/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.2216 - accuracy: 0.9267
# Epoch 75/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.1346 - accuracy: 0.9690
# Epoch 76/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.6919 - accuracy: 0.8496
# Epoch 77/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.2713 - accuracy: 0.9211
# Epoch 78/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.2100 - accuracy: 0.9358
# Epoch 79/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.1068 - accuracy: 0.9754
# Epoch 80/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1665 - accuracy: 0.9595
# Epoch 81/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0998 - accuracy: 0.9741
# Epoch 82/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.0944 - accuracy: 0.9750
# Epoch 83/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.3081 - accuracy: 0.9211
# Epoch 84/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.2932 - accuracy: 0.9263
# Epoch 85/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0771 - accuracy: 0.9832
# Epoch 86/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.0659 - accuracy: 0.9845
# Epoch 87/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0874 - accuracy: 0.9797
# Epoch 88/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.2319 - accuracy: 0.9319
# Epoch 89/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.2494 - accuracy: 0.9289
# Epoch 90/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1233 - accuracy: 0.9672
# Epoch 91/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0565 - accuracy: 0.9858
# Epoch 92/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0517 - accuracy: 0.9884
# Epoch 93/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0701 - accuracy: 0.9828
# Epoch 94/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.5525 - accuracy: 0.9159
# Epoch 95/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.6498 - accuracy: 0.8233
# Epoch 96/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1114 - accuracy: 0.9763
# Epoch 97/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0639 - accuracy: 0.9892
# Epoch 98/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0544 - accuracy: 0.9879
# Epoch 99/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1097 - accuracy: 0.9711
# Epoch 100/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0586 - accuracy: 0.9849
# Epoch 101/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1295 - accuracy: 0.9651
# Epoch 102/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.3439 - accuracy: 0.9211
# Epoch 103/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.1619 - accuracy: 0.9534
# Epoch 104/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0978 - accuracy: 0.9724
# Epoch 105/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.1372 - accuracy: 0.9603
# Epoch 106/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0981 - accuracy: 0.9772
# Epoch 107/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0960 - accuracy: 0.9759
# Epoch 108/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.0385 - accuracy: 0.9935
# Epoch 109/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0338 - accuracy: 0.9931
# Epoch 110/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0302 - accuracy: 0.9918
# Epoch 111/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1225 - accuracy: 0.9642
# Epoch 112/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.3484 - accuracy: 0.9259
# Epoch 113/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.4344 - accuracy: 0.8828
# Epoch 114/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0592 - accuracy: 0.9888
# Epoch 115/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0635 - accuracy: 0.9866
# Epoch 116/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0854 - accuracy: 0.9741
# Epoch 117/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0588 - accuracy: 0.9849
# Epoch 118/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.4391 - accuracy: 0.9000
# Epoch 119/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.2728 - accuracy: 0.9345
# Epoch 120/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.2295 - accuracy: 0.9440
# Epoch 121/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0502 - accuracy: 0.9909
# Epoch 122/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0415 - accuracy: 0.9905
# Epoch 123/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.3780 - accuracy: 0.9121
# Epoch 124/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1412 - accuracy: 0.9625
# Epoch 125/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0600 - accuracy: 0.9871
# Epoch 126/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0489 - accuracy: 0.9879
# Epoch 127/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0377 - accuracy: 0.9922
# Epoch 128/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0310 - accuracy: 0.9931
# Epoch 129/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0537 - accuracy: 0.9884
# Epoch 130/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0355 - accuracy: 0.9927
# Epoch 131/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1539 - accuracy: 0.9642
# Epoch 132/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.7180 - accuracy: 0.8319
# Epoch 133/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0789 - accuracy: 0.9759
# Epoch 134/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0513 - accuracy: 0.9884
# Epoch 135/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.8198 - accuracy: 0.8250
# Epoch 136/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1760 - accuracy: 0.9517
# Epoch 137/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1603 - accuracy: 0.9569
# Epoch 138/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1687 - accuracy: 0.9487
# Epoch 139/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0733 - accuracy: 0.9806
# Epoch 140/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0844 - accuracy: 0.9767
# Epoch 141/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0442 - accuracy: 0.9901
# Epoch 142/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0465 - accuracy: 0.9879
# Epoch 143/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0385 - accuracy: 0.9922
# Epoch 144/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.0335 - accuracy: 0.9931
# Epoch 145/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0211 - accuracy: 0.9966
# Epoch 146/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0321 - accuracy: 0.9931
# Epoch 147/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.3230 - accuracy: 0.9362
# Epoch 148/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.2078 - accuracy: 0.9444
# Epoch 149/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0605 - accuracy: 0.9853
# Epoch 150/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0683 - accuracy: 0.9853
# Epoch 151/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0471 - accuracy: 0.9879
# Epoch 152/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0228 - accuracy: 0.9970
# Epoch 153/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0231 - accuracy: 0.9953
# Epoch 154/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0546 - accuracy: 0.9849
# Epoch 155/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0444 - accuracy: 0.9918
# Epoch 156/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0423 - accuracy: 0.9892
# Epoch 157/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1811 - accuracy: 0.9556
# Epoch 158/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0343 - accuracy: 0.9905
# Epoch 159/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1221 - accuracy: 0.9746
# Epoch 160/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.2325 - accuracy: 0.9431
# Epoch 161/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.9348 - accuracy: 0.8284
# Epoch 162/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.3819 - accuracy: 0.8836
# Epoch 163/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1122 - accuracy: 0.9690
# Epoch 164/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1381 - accuracy: 0.9651
# Epoch 165/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0751 - accuracy: 0.9823
# Epoch 166/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0739 - accuracy: 0.9832
# Epoch 167/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1488 - accuracy: 0.9625
# Epoch 168/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0434 - accuracy: 0.9905
# Epoch 169/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0326 - accuracy: 0.9931
# Epoch 170/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0227 - accuracy: 0.9957
# Epoch 171/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0633 - accuracy: 0.9823
# Epoch 172/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.2449 - accuracy: 0.9453
# Epoch 173/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0977 - accuracy: 0.9741
# Epoch 174/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0783 - accuracy: 0.9793
# Epoch 175/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1478 - accuracy: 0.9698
# Epoch 176/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1719 - accuracy: 0.9543
# Epoch 177/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1333 - accuracy: 0.9707
# Epoch 178/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1476 - accuracy: 0.9616
# Epoch 179/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0359 - accuracy: 0.9931
# Epoch 180/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0413 - accuracy: 0.9914
# Epoch 181/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.0939 - accuracy: 0.9815
# Epoch 182/200
# 73/73 [==============================] - 1s 17ms/step - loss: 0.0993 - accuracy: 0.9754
# Epoch 183/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0651 - accuracy: 0.9858
# Epoch 184/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0243 - accuracy: 0.9974
# Epoch 185/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0177 - accuracy: 0.9970
# Epoch 186/200
# 73/73 [==============================] - 1s 19ms/step - loss: 0.0400 - accuracy: 0.9901
# Epoch 187/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0419 - accuracy: 0.9897
# Epoch 188/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1088 - accuracy: 0.9733
# Epoch 189/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0924 - accuracy: 0.9711
# Epoch 190/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0518 - accuracy: 0.9875
# Epoch 191/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0206 - accuracy: 0.9953
# Epoch 192/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0230 - accuracy: 0.9953
# Epoch 193/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0130 - accuracy: 0.9970
# Epoch 194/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0511 - accuracy: 0.9853
# Epoch 195/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0593 - accuracy: 0.9819
# Epoch 196/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0178 - accuracy: 0.9970
# Epoch 197/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0411 - accuracy: 0.9897
# Epoch 198/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.7732 - accuracy: 0.8655
# Epoch 199/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.1533 - accuracy: 0.9625
# Epoch 200/200
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0616 - accuracy: 0.9823

# %% [markdown]
# # 7. Saving model in H5 and TFJS format

# %%
model.save('model.h5')

# %%
model = tf.keras.models.load_model('model.h5')
tfjs.converters.save_keras_model(model, 'tfjs_model')
